# %%
import json
from datetime import datetime
import csv
import requests

from datetime import datetime

now = datetime.now()  # current date and time
year = now.strftime("%Y")
month = now.strftime("%m")
day = now.strftime("%d")
ora = now.strftime("%H_%M_%S")
ora_log = now.strftime("%H:%M:%S")
ora_estrazione = year + month + day + "_ora_" + ora

# definisco le variabili (tra la quali percorso file elenco, ecc)
path_lavoro = "C:\\Users\\ig01849\\Miei progetti\\EE\\EE API2\\Prova_23012020_1\\"
nome_file_log_api2query1 = "Api2Query1_LOG.csv"
nome_file_api2query1 = "Api2Query1_RES"
nome_file_api2query2 = "Api2Query2_RES"

# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @ VARIABILI PER API1 QUERY2                          @
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@




urlbase_api1query2 = "https://intesa.uat01.eesa.run/api/trade-codes?"
field_api2q2_field = "keyword"
field_api2q2_value = "latte"  # inserire VALUE = stringa da ricercare
field_api2q2_strict = "false"  # inserire STRICT valori: true o false
field_api2q2_language = "IT"  # inserire LANGUAGE valore: codice due digit es. EN, IT, ecc
separatore_valori = "&"

urlcompleted_api1query2 = urlbase_api1query2 + "field=" + field_api2q2_field + separatore_valori + "value=" + field_api2q2_value + separatore_valori + "strict=" + field_api2q2_strict + separatore_valori + "language=" + field_api2q2_language

# print("ulr: " + urlcompleted_api1query2)

# url = "https://intesa.uat01.eesa.run/api/trade-codes?field=keyword&value=milk&strict=false&language=EN"

# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ! CHIAMATA A API1 QUERY                              !
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# url = "https://intesa.uat01.eesa.run/api/trade-codes?field=keyword&value=milk&strict=false&language=EN"

payload = {}
headers = {
    'Authorization': 'Basic aW50ZXNhOjdqb0x2RFd5a21tTWR3NUc='
}

response = requests.request("GET", urlcompleted_api1query2, headers=headers, data=payload)

# response = requests.request("GET", url, headers=headers, data = payload)

print("RESPONSE\n")
print(response.text.encode('utf8'))
code_response = str(response.status_code)
code_response_code = response.status_code

# creo oggetto file testo per registrazione API2QUERY1:


file_log = open(path_lavoro + nome_file_log_api2query1, "a", encoding='utf-8')

if code_response_code != 200:
    print(
        "CHIAMATA API2 QUERY2 CON CODE: " + "\n" + code_response + "\n" + "IMPOSSIBILE PROCEDERE CON LA SUCCESSIVA ELABORAZIONE")
    content_log = ora_log + ";" + str(
        year + month + day) + ";" + urlcompleted_api1query2 + ";" + code_response + ";CODE<>200:NESSUN RISULTATO"
    file_log.write(content_log + "\n")  # stampo la stringa + a capo nel file
    file_log.close()  # chiudo l'oggetto file
else:
    # nome_file_completo_api2q1 = ora_estrazione + nome_file_api2query1 + ".csv"
    # file_api2q1 = open(path_lavoro + nome_file_completo_api2q1, "a", encoding='utf-8')

    # carico nell'oggetto data il file json
    data = json.loads(response.text)
    # scrivo il numero di item nel file di log; totalItems
    totalItems = data["totalItems"]
    content_log = ora_log + ";" + str(year) + str(month) + str(
        day) + ";" + urlcompleted_api1query2 + ";" + code_response + ";" + str(totalItems)
    file_log.write(content_log + "\n")  # stampo la stringa + a capo nel file
    file_log.close()  # chiudo l'oggetto file
    # itero sugli elementi di api2q1 + q2 e scrivo nei relativi file dei risultati

    intestazioni_file_api2q1 = "ORA ESTRAZIONE;DATA ESTRAZIONE;CLASSIFICATION;LEVEL;MAX_LEVEL ;CODE;PARENT_CODE ;GROUP;PATH;DESCRIPTION;ULR;STATUS;N.ITEM API2Q2"
    nome_file_completo_api2q1 = ora_estrazione + nome_file_api2query1 + ".csv"
    file_registrazione_api2q1 = open(path_lavoro + nome_file_completo_api2q1, "a", encoding='utf-8')
    file_registrazione_api2q1.write(intestazioni_file_api2q1 + "\n")  # stampo la stringa + a capo nel file

    #intestazioni_file_api2q2 = "ORA ESTRAZIONE;DATA ESTRAZIONE;CLASSIFICATION;LEVEL;MAX_LEVEL ;CODE;PARENT_CODE ;GROUP;PATH;DESCRIPTION;ULR"
    intestazioni_file_api2q2 = "ORA ESTRAZIONE;DATA ESTRAZIONE;CLASSIFICATION_L1_API2Q1;LEVEL_L1_API2Q1;MAX_LEVEL_L1_API2Q1;CODE_L1_API2Q1;PARENT_CODE_L1_API2Q1;GROUP_L1_API2Q1;PATH_L1_API2Q1;DESCRIPTION_L1_API2Q1;CLASSIFICATION;LEVEL;MAX_LEVEL ;CODE;PARENT_CODE ;GROUP;PATH;DESCRIPTION;ULR"
    nome_file_completo_api2q2 = ora_estrazione + nome_file_api2query2 + ".csv"
    file_registrazione_api2q2 = open(path_lavoro + nome_file_completo_api2q2, "a", encoding='utf-8')
    file_registrazione_api2q2.write(intestazioni_file_api2q2 + "\n")  # stampo la stringa + a capo nel file

    items = data["items"]  # entro dentro items che contiene le informazioni sugli items
    dizionario_data = {}
    print("ITEMS API2QUERY2: " + str(items))
    for n in items:  # entro dentro item
        dizionario_data = n
        # code = dizionario_data["code"]
        # print(dizionario_data["code"])
        classification = str(dizionario_data["classification"])
        print(classification)
        level = str(dizionario_data["level"])
        max_level = str(dizionario_data["max_level"])
        code = str(dizionario_data["code"])
        parent_code = str(dizionario_data["parent_code"])
        group = str(dizionario_data["group"])
        path = str(dizionario_data["path"])
        description = str(dizionario_data["description"])
        # stringa_api1q2 = classification + ";" + level + ";" + max_level
        # print("stringa_api1q2")

        #   ------   INIZIO CLICO SU API2Q2 - creo ulr api2q2
        url_base_api2q2 = "https://intesa.uat01.eesa.run/api/trade-codes/hierarchy?"
        #
        url_base_api2q2_composta = url_base_api2q2 + "classification=" + classification + separatore_valori + "codeValue=" + code + separatore_valori + "language=" + field_api2q2_language
        # print("URL DI PAI2 QUERY2: " + url_base_api2q2_composta)

        ############### DA PORTARE GIù AGGIUNGENDO LO STATUS ED IL NUMERO DI ITEM
        # content_api2q1 = ora_log + ";" + str(
          #  year + month + day) + ";" + classification + ";" + level + ";" + max_level + ";" + code + ";" + parent_code + ";" + group + ";" + path + ";" + chr(
           # 34) + description + chr(34) + ";" + url_base_api2q2_composta
        #file_registrazione_api2q1.write(content_api2q1 + "\n")  # stampo la stringa + a capo nel file


        # richiamo api2q2
        payload = {}
        headers = {
            'Authorization': 'Basic aW50ZXNhOjdqb0x2RFd5a21tTWR3NUc='
        }

        response_api2q2 = requests.request("GET", url_base_api2q2_composta, headers=headers, data=payload)
        data_api2q2 = json.loads(response_api2q2.text)

        code_response_api2q2 = str(response_api2q2.status_code)
        code_response_code_api2q2 = response_api2q2.status_code

        # nome_file_completo_api1q2 = ora_estrazione + nome_file_api2query2 + ".csv"
        # file_registrazione_api2q1 = open(path_lavoro + nome_file_completo_api1q1,"a",encoding='utf-8')
        #
        if code_response_code_api2q2 != 200:
            print("LA CHIAMATA A API2 Q2 CON CODICE: " + code + " FALLISCE")
            content_api1q1 = ora_log + ";" + str(year + month + day) + ";" + classification + ";" + level + ";" + max_level + ";" + code + ";" + parent_code + ";" + group + ";" + path + ";" + description + ";" + url_base_api2q2_composta + ";" + code_response_api2q2 + "API2Q2 IN ERRORE NO ITEMS"
            file_registrazione_api2q1.write(content_api1q1 + "\n")  # stampo la stringa + a capo nel file
        #     # content_log = ora_log + ";" + str(year + month + day) + ";" + url_base_api2q2_composta + ";" + code_response + ";CODE<>200:NESSUN RISULTATO"
        #     # file_log.write(content_log + "\n") # stampo la stringa + a capo nel file
        #     # file_log.close() # chiudo l'oggetto file
        #     ###### MANCA REGISTRAZIONE CASO NEGATIVO
        else:
            nome_file_completo_api2q2 = ora_estrazione + nome_file_api2query2 + ".csv"
            file_api2q2 = open(path_lavoro + nome_file_completo_api2q2, "a", encoding='utf-8')
        #     # carico nell'oggetto data il file json
            data_api2q2 = json.loads(response_api2q2.text)
        #     # scrivo il numero di item nel file dei risultati di api2q1 totalItems
            totalItems = str(data_api2q2["totalItems"])
            content_api1q1 = ora_log + ";" + str(year + month + day) + ";" + classification + ";" + level + ";" + max_level + ";" + code + ";" + parent_code + ";" + group + ";" + path + ";" + chr(34) + description + chr(34) + ";" + url_base_api2q2_composta + ";" + code_response_api2q2 + ";" + totalItems
            content_api1q1_for_api2iq2 = ora_log + ";" + str(year + month + day) + ";" + classification + ";" + level + ";" + max_level + ";" + code + ";" + parent_code + ";" + group + ";" + path + ";" + chr(34) + description + chr(34)
            file_registrazione_api2q1.write(content_api1q1 + "\n")  # stampo la stringa + a capo nel file
        #
            items_api2q2 = data_api2q2["items"]
            dict_items_api2q2 = {}
            for z in items_api2q2:
        #         print(z)
                dict_items_api2q2 = z
                code = dict_items_api2q2["code"]
                classification_api2q2 = str(dict_items_api2q2["classification"])
                level_api2q2 = str(dict_items_api2q2["level"])
                max_level_api2q2 = str(dict_items_api2q2["max_level"])
                code_api2q2 = str(dict_items_api2q2["code"])
                parent_code_api2q2 = str(dict_items_api2q2["parent_code"])
                group_api2q2 = str(dict_items_api2q2["group"])
                path_api2q2 = str(dict_items_api2q2["path"])
                description_api2q2 = str(dict_items_api2q2["description"])
                #content_api2q2 = ora_log + ";" + str(year + month + day) + ";" + classification_api2q2 + ";" + level_api2q2 + ";" + max_level_api2q2 + ";" + code_api2q2 + ";" + parent_code_api2q2 + ";" + group_api2q2 + ";" + path_api2q2 + ";" + chr(34) + description_api2q2 + chr(34) + ";" + url_base_api2q2_composta
                content_api2q2 = classification_api2q2 + ";" + level_api2q2 + ";" + max_level_api2q2 + ";" + code_api2q2 + ";" + parent_code_api2q2 + ";" + group_api2q2 + ";" + path_api2q2 + ";" + chr(
            34) + description_api2q2 + chr(34) + ";" + url_base_api2q2_composta
                file_registrazione_api2q2.write(content_api1q1_for_api2iq2 + content_api2q2 + "\n")

    file_registrazione_api2q2.close()
    file_registrazione_api2q1.close()
    # content_log = ora_log + ";" + str(year) + str(month) + str(day) + ";" + urlcompleted_api1query2 + ";" + code_response + ";" + str(totalItems)
    # file_log.write(content_log + "\n")  # stampo la stringa + a capo nel file
    # file_log.close()  # chiudo l'oggetto file

    # chiudo il file dei risultati di api2q1
    # file_registrazione_api2q1.close()

print("""

______ _____ _   _ _____ _____ _____ _ _ _ 
|  ___|_   _| \ | |_   _|_   _|  _  | | | |
| |_    | | |  \| | | |   | | | | | | | | |
|  _|   | | | . ` | | |   | | | | | | | | |
| |    _| |_| |\  |_| |_  | | \ \_/ /_|_|_|
\_|    \___/\_| \_/\___/  \_/  \___/(_|_|_)



""")
# Out:
# RESPONSE
#
# ...
